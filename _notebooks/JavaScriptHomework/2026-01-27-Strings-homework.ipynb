# %% [markdown]
# ## Homework
#
# **Requirements:**
#
# - Include three strings of varying lengths
# - Find the length of each string and print them
# - Find the first and last character of each string and print them
# - Concatenate all three strings into a sentence and print the result

# %%
# %%js
#
# const bob = "Bob";
# const nick = "Nick";
# const dutch = "Dutch";
#
# console.log(`Length of Bob's name: ${bob.length}`);
# console.log(`The first letter of Bob's name is '${bob[0]}', and the last letter is '${bob[bob.length - 1]}'.`);
# console.log();
#
# console.log(`Length of Nick's name: ${nick.length}`);
# console.log(`The first letter of Nick's name is '${nick[0]}', and the last letter is '${nick[nick.length - 1]}'.`);
# console.log();
#
#
# console.log(`Length of Dutch's name: ${dutch.length}`);
# console.log(`The first letter of Dutch's name is '${dutch[0]}', and the last letter is '${dutch[dutch.length - 1]}'.`);
# console.log();
#
# console.log(`${bob}, ${nick}, and ${dutch} are all in high school`);
